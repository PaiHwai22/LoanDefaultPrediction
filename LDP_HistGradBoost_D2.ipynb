# %% [markdown]
# **Importing Libraries**

# %%
# libraries
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt  # plotting simple plots
import numpy as np  # linear algebra
import os  # access directory structure
import pandas as pd  # data processing
import seaborn as sns  # plotting visual plots
from sklearn.model_selection import train_test_split # data splits
from sklearn.preprocessing import MinMaxScaler # for normalizing data

import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression # model import (logistic regression)

# %%
# Logistic Regression
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve, auc

# %% [markdown]
# **data preprocessing and feature engineering techniques**
#
#
# ---
# * create new binary features
# * string to float conversions
# * one-hot-encode for object dtype
# * feature scaling
# * engineer new features
# * drop unnecessary columns

# %% [markdown]
# **Data Pre-Processing**

# %%
# Read csv files into df
UserInfo = pd.read_csv('/content/user_info.csv', index_col = 0)
NextMonths = pd.read_csv('/content/next_months.csv', index_col = 0)
PastMonths = pd.read_csv('/content/past_months.csv', index_col = 0)

# %%
# Merge dataframes
merged_data = pd.merge(NextMonths, PastMonths, how='outer')
merged_data = pd.merge(merged_data, UserInfo, on='user_id', how='inner')

# %%
merged_data.head()
# Out:
#         month  default_value  user_id registration_date  years_of_study  \
# 0  2013-11-01              0   821302        2012-01-21             1.0
# 1  2013-10-01              0   821302        2012-01-21             1.0
# 2  2013-09-01              0   821302        2012-01-21             1.0
# 3  2013-08-01              0   821302        2012-01-21             1.0
# 4  2013-07-01              0   821302        2012-01-21             1.0
#
#    family_size  loan_amount  total_career_years  birth_date contract_type  \
# 0          0.0       187956                 3.0  1987-10-15             A
# 1          0.0       187956                 3.0  1987-10-15             A
# 2          0.0       187956                 3.0  1987-10-15             A
# 3          0.0       187956                 3.0  1987-10-15             A
# 4          0.0       187956                 3.0  1987-10-15             A
#
#    is_male province  zip_code   age group history_type  monthly_expense
# 0      0.0        A  300057.0  24.0     A            A          14500.0
# 1      0.0        A  300057.0  24.0     A            A          14500.0
# 2      0.0        A  300057.0  24.0     A            A          14500.0
# 3      0.0        A  300057.0  24.0     A            A          14500.0
# 4      0.0        A  300057.0  24.0     A            A          14500.0

# %%
# the current default_value column is listed as 0 and none 0. We want to change this to 0, 1 values to help in categorization.
merged_data['default_value'] = merged_data['default_value'].where(merged_data['default_value'] == 0, 1)

# %% [markdown]
# **Train Test Split**

# %%
# setting seed to generate new numbers on each run
seed = 1

# %%
# Split the merged data into training and testing sets
X = merged_data.loc[:, merged_data.columns != 'default_value']
y = merged_data.loc[:,merged_data.columns == 'default_value']

# split train test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %%
# inspecting our target feature
y_train.head()
# Out:
#         default_value
# 9660                0
# 95690               0
# 67339               0
# 127206              0
# 27022               0

# %%
# Create a bar plot
y_train['default_value'].value_counts().plot(kind='bar', color=['blue', 'orange'])

# Set plot labels and title
plt.xlabel('default_value')
plt.ylabel('Count')
plt.title('Bar Plot of default_value')
# Out:
# Text(0.5, 1.0, 'Bar Plot of default_value')

# %%
y_train['default_value'].value_counts()
# Out:
# 0    102405
# 1     21247
# Name: default_value, dtype: int64

# %% [markdown]
# ---
#
# *`We make a note to resample our target feature to balance the weights. `*
#
# ---

# %%
X_train.head()
# Out:
#              month  user_id registration_date  years_of_study  family_size  \
# 9660    2013-07-01   842896        2012-04-02             NaN          3.0
# 95690   2012-09-01   848896        2012-09-02             1.0          0.0
# 67339   2013-09-01  1012539        2012-05-30            14.0          0.0
# 127206  2012-07-01   804473        2012-08-01             NaN          0.0
# 27022   2013-02-01   814477        2012-01-15             1.0          0.0
#
#         loan_amount  total_career_years  birth_date contract_type  is_male  \
# 9660         141642                 NaN  2061-01-01             E      1.0
# 95690        158625                 1.0  2063-05-16             E      1.0
# 67339        141642                14.0  1978-02-19             A      1.0
# 127206       142734                 NaN  1988-04-24             E      1.0
# 27022        157695                 1.0  1991-08-25             D      1.0
#
#        province  zip_code   age group history_type  monthly_expense
# 9660          G  611312.0  51.0     B            B          12000.0
# 95690         L  582022.0  49.0     B            A          20000.0
# 67339         K  280001.0  34.0     B            A          22000.0
# 127206        E  661111.0  24.0     A            C          12000.0
# 27022         I  183124.0  20.0     B            B          12000.0

# %%
# Inspect Null Values in Train
nRow, nCol = X_train.shape
print(f" Train features has {nRow} rows and {nCol} columns. \n")
null_columns = X_train.isnull().sum().sort_values(ascending=False)
print(f"Columns with null values: \n{null_columns[null_columns > 0]}")
# Out:
#  Train features has 123652 rows and 16 columns.
#
# Columns with null values:
# years_of_study        87114
# total_career_years    87114
# history_type            225
# dtype: int64

# %%
# Visualize Null Features in Train Data
# Create a figure with two subplots
plt.figure(figsize=(12, 4))

# Plot the distribution of 'years_of_study' on the left
plt.subplot(121)
sns.distplot(X_train['years_of_study'])
plt.title('Distribution of Years of Study')

# Plot the distribution of 'total_career_years' on the right
plt.subplot(122)
sns.distplot(X_train['total_career_years'])
plt.title('Distribution of Total Career Years')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Create a joint distribution plot to visualize the distribution and relationship
sns.jointplot(x='years_of_study', y='total_career_years', data=X_train, kind='reg')

plt.show()

# %%
# Calculate the correlation coefficient (Pearson's)
correlation_coefficient = X_train['years_of_study'].corr(X_train['total_career_years'])
print(f'Correlation coefficient: {correlation_coefficient}')
# Out:
# Correlation coefficient: 0.9461815305530442

# %% [markdown]
# **`Feature Engineering`**

# %%
## copy train to df for testing
df = X_train.copy()

# %%
# combine correlated variables and drop columns to reduce multicolinearity
df['edu_career_years'] = df.apply(lambda x: x['total_career_years'] + x['years_of_study'],axis=1)
df = df.drop(['total_career_years','years_of_study'],axis=1)
df.head()
# Out:
#              month  user_id registration_date  family_size  loan_amount  \
# 9660    2013-07-01   842896        2012-04-02          3.0       141642
# 95690   2012-09-01   848896        2012-09-02          0.0       158625
# 67339   2013-09-01  1012539        2012-05-30          0.0       141642
# 127206  2012-07-01   804473        2012-08-01          0.0       142734
# 27022   2013-02-01   814477        2012-01-15          0.0       157695
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 9660    2061-01-01             E      1.0        G  611312.0  51.0     B
# 95690   2063-05-16             E      1.0        L  582022.0  49.0     B
# 67339   1978-02-19             A      1.0        K  280001.0  34.0     B
# 127206  1988-04-24             E      1.0        E  661111.0  24.0     A
# 27022   1991-08-25             D      1.0        I  183124.0  20.0     B
#
#        history_type  monthly_expense  edu_career_years
# 9660              B          12000.0               NaN
# 95690             A          20000.0               2.0
# 67339             A          22000.0              28.0
# 127206            C          12000.0               NaN
# 27022             B          12000.0               2.0

# %%
## apply this new feature to test set as well
X_test['edu_career_years'] = X_test.apply(lambda x: x['total_career_years'] + x['years_of_study'],axis=1)
X_test = X_test.drop(['total_career_years','years_of_study'],axis=1)
X_test.head()
# Out:
#              month  user_id registration_date  family_size  loan_amount  \
# 48176   2012-08-01   981768        2012-11-05          2.0       108378
# 89187   2013-06-01   976840        2012-06-05          2.0       153996
# 128178  2012-07-01   838565        2012-01-30          4.0       165399
# 25482   2012-07-01   797763        2012-04-01          0.0       135321
# 68298   2013-02-01  1020410        2012-02-06          2.0       171408
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 48176   1987-02-14             B      1.0        E  659130.0  25.0     B
# 89187   1989-08-03             A      1.0        A  344808.0  23.0     B
# 128178  1985-01-01             E      1.0        G  622150.0  27.0     B
# 25482   1988-02-01             E      1.0        I  182007.0  24.0     A
# 68298   1967-02-25             D      1.0        K  287810.0  45.0     B
#
#        history_type  monthly_expense  edu_career_years
# 48176             B          13000.0               4.0
# 89187             A           9500.0               6.0
# 128178            C          15000.0               NaN
# 25482             B          15000.0               NaN
# 68298             C          20000.0               NaN

# %% [markdown]
# # New Section

# %%
# check new feature column
df['edu_career_years'].describe()
# Out:
# count    36538.000000
# mean        13.006432
# std         12.947581
# min          0.000000
# 25%          4.000000
# 50%          8.000000
# 75%         16.000000
# max         81.000000
# Name: edu_career_years, dtype: float64

# %%
# set layout
plt.figure(figsize=(12, 4))

# Plot the distribution of 'edu_career_years'
plt.subplot(122)
sns.distplot(df['edu_career_years'])
plt.title('Distribution of Total Education and Career Years')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
# boxplot of skewed features
sns.boxplot(x = df['edu_career_years'])
plt.show()

# %%
#create a function to find outliers using IQR
def find_outliers_IQR(df):
   q1=df.quantile(0.25)
   q3=df.quantile(0.75)
   IQR=q3-q1
   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
   return outliers

# %%
# find outliers
outliers = find_outliers_IQR(df['edu_career_years'])
outliers
# Out:
# 88045     50.0
# 29820     60.0
# 113238    40.0
# 146963    36.0
# 41600     40.0
#           ...
# 138952    60.0
# 142310    60.0
# 37403     64.0
# 133105    50.0
# 120809    60.0
# Name: edu_career_years, Length: 2820, dtype: float64

# %%
# drop outliers
df['edu_career_years'] = (df['edu_career_years']).drop(outliers.index)

# %%
# check column after dropping outliers
sns.boxplot(x = df['edu_career_years'])
plt.show()

# %%
# check missing values
df['edu_career_years'].isnull().sum()
# Out:
# 89934

# %%
# count non missing values
df['edu_career_years'].count()
# Out:
# 33718

# %% [markdown]
# **Impute Missing Values with MICE**

# %%
# import and enable MICE
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
# Define imputer
imputer = IterativeImputer(random_state=100, max_iter=100)

# %%
df.head()
# Out:
#              month  user_id registration_date  family_size  loan_amount  \
# 9660    2013-07-01   842896        2012-04-02          3.0       141642
# 95690   2012-09-01   848896        2012-09-02          0.0       158625
# 67339   2013-09-01  1012539        2012-05-30          0.0       141642
# 127206  2012-07-01   804473        2012-08-01          0.0       142734
# 27022   2013-02-01   814477        2012-01-15          0.0       157695
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 9660    2061-01-01             E      1.0        G  611312.0  51.0     B
# 95690   2063-05-16             E      1.0        L  582022.0  49.0     B
# 67339   1978-02-19             A      1.0        K  280001.0  34.0     B
# 127206  1988-04-24             E      1.0        E  661111.0  24.0     A
# 27022   1991-08-25             D      1.0        I  183124.0  20.0     B
#
#        history_type  monthly_expense  edu_career_years
# 9660              B          12000.0               NaN
# 95690             A          20000.0               2.0
# 67339             A          22000.0              28.0
# 127206            C          12000.0               NaN
# 27022             B          12000.0               2.0

# %%
# concat target feature to df
df = pd.concat([df, y_train.copy()], axis=1)

# %%
df.head()
# Out:
#              month  user_id registration_date  family_size  loan_amount  \
# 9660    2013-07-01   842896        2012-04-02          3.0       141642
# 95690   2012-09-01   848896        2012-09-02          0.0       158625
# 67339   2013-09-01  1012539        2012-05-30          0.0       141642
# 127206  2012-07-01   804473        2012-08-01          0.0       142734
# 27022   2013-02-01   814477        2012-01-15          0.0       157695
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 9660    2061-01-01             E      1.0        G  611312.0  51.0     B
# 95690   2063-05-16             E      1.0        L  582022.0  49.0     B
# 67339   1978-02-19             A      1.0        K  280001.0  34.0     B
# 127206  1988-04-24             E      1.0        E  661111.0  24.0     A
# 27022   1991-08-25             D      1.0        I  183124.0  20.0     B
#
#        history_type  monthly_expense  edu_career_years  default_value
# 9660              B          12000.0               NaN              0
# 95690             A          20000.0               2.0              0
# 67339             A          22000.0              28.0              0
# 127206            C          12000.0               NaN              0
# 27022             B          12000.0               2.0              0

# %%
# Use numerical features
imp_train = df.loc[:, ['user_id', 'family_size', 'loan_amount','is_male', 'zip_code', 'age', 'monthly_expense', 'edu_career_years', 'default_value']]
imp_train.head()
# Out:
#         user_id  family_size  loan_amount  is_male  zip_code   age  \
# 9660     842896          3.0       141642      1.0  611312.0  51.0
# 95690    848896          0.0       158625      1.0  582022.0  49.0
# 67339   1012539          0.0       141642      1.0  280001.0  34.0
# 127206   804473          0.0       142734      1.0  661111.0  24.0
# 27022    814477          0.0       157695      1.0  183124.0  20.0
#
#         monthly_expense  edu_career_years  default_value
# 9660            12000.0               NaN              0
# 95690           20000.0               2.0              0
# 67339           22000.0              28.0              0
# 127206          12000.0               NaN              0
# 27022           12000.0               2.0              0

# %%
# fit on the dataset
imputer.fit(imp_train)
# Out:
# IterativeImputer(max_iter=100, random_state=100)

# %%
# predict missing values
df_imputed = imputer.transform(imp_train)

# %%
df_imputed[:10]
# Out:
# array([[8.42896000e+05, 3.00000000e+00, 1.41642000e+05, 1.00000000e+00,
#         6.11312000e+05, 5.10000000e+01, 1.20000000e+04, 1.59021021e+01,
#         0.00000000e+00],
#        [8.48896000e+05, 0.00000000e+00, 1.58625000e+05, 1.00000000e+00,
#         5.82022000e+05, 4.90000000e+01, 2.00000000e+04, 2.00000000e+00,
#         0.00000000e+00],
#        [1.01253900e+06, 0.00000000e+00, 1.41642000e+05, 1.00000000e+00,
#         2.80001000e+05, 3.40000000e+01, 2.20000000e+04, 2.80000000e+01,
#         0.00000000e+00],
#        [8.04473000e+05, 0.00000000e+00, 1.42734000e+05, 1.00000000e+00,
#         6.61111000e+05, 2.40000000e+01, 1.20000000e+04, 5.79167471e+00,
#         0.00000000e+00],
#        [8.14477000e+05, 0.00000000e+00, 1.57695000e+05, 1.00000000e+00,
#         1.83124000e+05, 2.00000000e+01, 1.20000000e+04, 2.00000000e+00,
#         0.00000000e+00],
#        [9.93124000e+05, 0.00000000e+00, 1.55382000e+05, 1.00000000e+00,
#         2.87130000e+05, 4.50000000e+01, 1.50000000e+05, 2.13744329e+01,
#         1.00000000e+00],
#        [8.23032000e+05, 3.00000000e+00, 1.35321000e+05, 1.00000000e+00,
#         1.02131000e+05, 2.40000000e+01, 1.50000000e+04, 9.65544193e+00,
#         0.00000000e+00],
#        [9.99448000e+05, 3.00000000e+00, 1.65399000e+05, 1.00000000e+00,
#         3.44103000e+05, 3.40000000e+01, 3.00000000e+04, 1.26149707e+01,
#         0.00000000e+00],
#        [1.01617500e+06, 1.00000000e+00, 1.44036000e+05, 0.00000000e+00,
#         2.80019000e+05, 5.20000000e+01, 1.50000000e+04, 1.57383145e+01,
#         0.00000000e+00],
#        [1.06514800e+06, 0.00000000e+00, 1.44717000e+05, 1.00000000e+00,
#         2.82424000e+05, 3.70000000e+01, 4.00000000e+04, 1.27230258e+01,
#         0.00000000e+00]])

# %%
# Replace with imputed values
df.loc[:, ['user_id', 'family_size', 'loan_amount','is_male', 'zip_code', 'age', 'monthly_expense', 'edu_career_years', 'default_value']] = df_imputed
df.head(10)
# Out:
#              month    user_id registration_date  family_size  loan_amount  \
# 9660    2013-07-01   842896.0        2012-04-02          3.0     141642.0
# 95690   2012-09-01   848896.0        2012-09-02          0.0     158625.0
# 67339   2013-09-01  1012539.0        2012-05-30          0.0     141642.0
# 127206  2012-07-01   804473.0        2012-08-01          0.0     142734.0
# 27022   2013-02-01   814477.0        2012-01-15          0.0     157695.0
# 65671   2013-11-01   993124.0        2012-05-18          0.0     155382.0
# 18702   2013-09-01   823032.0        2012-01-22          3.0     135321.0
# 89516   2012-12-01   999448.0        2012-05-21          3.0     165399.0
# 67726   2012-08-01  1016175.0        2012-05-31          1.0     144036.0
# 72066   2013-08-01  1065148.0        2012-06-30          0.0     144717.0
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 9660    2061-01-01             E      1.0        G  611312.0  51.0     B
# 95690   2063-05-16             E      1.0        L  582022.0  49.0     B
# 67339   1978-02-19             A      1.0        K  280001.0  34.0     B
# 127206  1988-04-24             E      1.0        E  661111.0  24.0     A
# 27022   1991-08-25             D      1.0        I  183124.0  20.0     B
# 65671   1967-06-19             E      1.0        K  287130.0  45.0     B
# 18702   1988-03-02             C      1.0        I  102131.0  24.0     B
# 89516   1978-02-01             E      1.0        A  344103.0  34.0     B
# 67726   2060-08-10             E      0.0        K  280019.0  52.0     B
# 72066   1975-01-28             D      1.0        K  282424.0  37.0     B
#
#        history_type  monthly_expense  edu_career_years  default_value
# 9660              B          12000.0         15.902102            0.0
# 95690             A          20000.0          2.000000            0.0
# 67339             A          22000.0         28.000000            0.0
# 127206            C          12000.0          5.791675            0.0
# 27022             B          12000.0          2.000000            0.0
# 65671             C         150000.0         21.374433            1.0
# 18702             C          15000.0          9.655442            0.0
# 89516             C          30000.0         12.614971            0.0
# 67726             C          15000.0         15.738315            0.0
# 72066             A          40000.0         12.723026            0.0

# %%
df.isnull().sum()
# Out:
# month                  0
# user_id                0
# registration_date      0
# family_size            0
# loan_amount            0
# birth_date             0
# contract_type          0
# is_male                0
# province               0
# zip_code               0
# age                    0
# group                  0
# history_type         225
# monthly_expense        0
# edu_career_years       0
# default_value          0
# dtype: int64

# %%
# drop rows with missing values
df = df.dropna()
df.isnull().sum()
# Out:
# month                0
# user_id              0
# registration_date    0
# family_size          0
# loan_amount          0
# birth_date           0
# contract_type        0
# is_male              0
# province             0
# zip_code             0
# age                  0
# group                0
# history_type         0
# monthly_expense      0
# edu_career_years     0
# default_value        0
# dtype: int64

# %%
# check y_train shape
y_train.shape
# Out:
# (123652, 1)

# %%
# replace y_train with df target feature column where missing value rows are dropped
y_train = df['default_value']

# %%
y_train.shape
# Out:
# (123427,)

# %%
# drop target feature column
df = df.drop('default_value', axis=1)

# %%
df.head()
# Out:
#              month    user_id registration_date  family_size  loan_amount  \
# 9660    2013-07-01   842896.0        2012-04-02          3.0     141642.0
# 95690   2012-09-01   848896.0        2012-09-02          0.0     158625.0
# 67339   2013-09-01  1012539.0        2012-05-30          0.0     141642.0
# 127206  2012-07-01   804473.0        2012-08-01          0.0     142734.0
# 27022   2013-02-01   814477.0        2012-01-15          0.0     157695.0
#
#         birth_date contract_type  is_male province  zip_code   age group  \
# 9660    2061-01-01             E      1.0        G  611312.0  51.0     B
# 95690   2063-05-16             E      1.0        L  582022.0  49.0     B
# 67339   1978-02-19             A      1.0        K  280001.0  34.0     B
# 127206  1988-04-24             E      1.0        E  661111.0  24.0     A
# 27022   1991-08-25             D      1.0        I  183124.0  20.0     B
#
#        history_type  monthly_expense  edu_career_years
# 9660              B          12000.0         15.902102
# 95690             A          20000.0          2.000000
# 67339             A          22000.0         28.000000
# 127206            C          12000.0          5.791675
# 27022             B          12000.0          2.000000

# %%
df.shape
# Out:
# (123427, 15)

# %%
# Apply the engineered features on Train
X_train = df.copy()

# %%
# Pre processing function
def preprocess_dataframe(df):

    # Define the list of string columns to remove special characters and convert to float
    string_columns = ['registration_date', 'birth_date', 'month']

    # Remove special characters from string columns
    df[string_columns] = df[string_columns].replace(r'\W', '', regex=True)

    # Convert string columns to float
    df[string_columns] = df[string_columns].astype(float)

    # Create dummy variables for categorical columns
    df_dummies = pd.get_dummies(df[['contract_type', 'province', 'group', 'history_type']], drop_first=True)

    # Concatenate the dummy variables with the original DataFrame
    df = pd.concat([df, df_dummies], axis=1)

    # Drop the original categorical columns
    df = df.drop(['contract_type', 'province', 'group', 'history_type'], axis=1)

    return df

# %%
X_train = preprocess_dataframe(X_train)

# %%
X_train.head()
# Out:
#              month    user_id  registration_date  family_size  loan_amount  \
# 9660    20130701.0   842896.0         20120402.0          3.0     141642.0
# 95690   20120901.0   848896.0         20120902.0          0.0     158625.0
# 67339   20130901.0  1012539.0         20120530.0          0.0     141642.0
# 127206  20120701.0   804473.0         20120801.0          0.0     142734.0
# 27022   20130201.0   814477.0         20120115.0          0.0     157695.0
#
#         birth_date  is_male  zip_code   age  monthly_expense  ...  province_L  \
# 9660    20610101.0      1.0  611312.0  51.0          12000.0  ...           0
# 95690   20630516.0      1.0  582022.0  49.0          20000.0  ...           1
# 67339   19780219.0      1.0  280001.0  34.0          22000.0  ...           0
# 127206  19880424.0      1.0  661111.0  24.0          12000.0  ...           0
# 27022   19910825.0      1.0  183124.0  20.0          12000.0  ...           0
#
#         province_M  province_N  province_O  group_B  group_C  group_D  \
# 9660             0           0           0        1        0        0
# 95690            0           0           0        1        0        0
# 67339            0           0           0        1        0        0
# 127206           0           0           0        0        0        0
# 27022            0           0           0        1        0        0
#
#         history_type_B  history_type_C  history_type_D
# 9660                 1               0               0
# 95690                0               0               0
# 67339                0               0               0
# 127206               0               1               0
# 27022                1               0               0
#
# [5 rows x 35 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123427 entries, 9660 to 128037
# Data columns (total 35 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   month              123427 non-null  float64
#  1   user_id            123427 non-null  float64
#  2   registration_date  123427 non-null  float64
#  3   family_size        123427 non-null  float64
#  4   loan_amount        123427 non-null  float64
#  5   birth_date         123427 non-null  float64
#  6   is_male            123427 non-null  float64
#  7   zip_code           123427 non-null  float64
#  8   age                123427 non-null  float64
#  9   monthly_expense    123427 non-null  float64
#  10  edu_career_years   123427 non-null  float64
#  11  contract_type_B    123427 non-null  uint8
#  12  contract_type_C    123427 non-null  uint8
#  13  contract_type_D    123427 non-null  uint8
#  14  contract_type_E    123427 non-null  uint8
#  15  province_B         123427 non-null  uint8
#  16  province_C         123427 non-null  uint8
#  17  province_D         123427 non-null  uint8
#  18  province_E         123427 non-null  uint8
#  19  province_F         123427 non-null  uint8
#  20  province_G         123427 non-null  uint8
#  21  province_H         123427 non-null  uint8
#  22  province_I         123427 non-null  uint8
#  23  province_J         123427 non-null  uint8
#  24  province_K         123427 non-null  uint8
#  25  province_L         123427 non-null  uint8
#  26  province_M         123427 non-null  uint8
#  27  province_N         123427 non-null  uint8
#  28  province_O         123427 non-null  uint8
#  29  group_B            123427 non-null  uint8
#  30  group_C            123427 non-null  uint8
#  31  group_D            123427 non-null  uint8
#  32  history_type_B     123427 non-null  uint8
#  33  history_type_C     123427 non-null  uint8
#  34  history_type_D     123427 non-null  uint8
# dtypes: float64(11), uint8(24)
# memory usage: 14.1 MB

# %%
X_test = preprocess_dataframe(X_test)

# %%
X_test.head()
# Out:
#              month  user_id  registration_date  family_size  loan_amount  \
# 48176   20120801.0   981768         20121105.0          2.0       108378
# 89187   20130601.0   976840         20120605.0          2.0       153996
# 128178  20120701.0   838565         20120130.0          4.0       165399
# 25482   20120701.0   797763         20120401.0          0.0       135321
# 68298   20130201.0  1020410         20120206.0          2.0       171408
#
#         birth_date  is_male  zip_code   age  monthly_expense  ...  province_L  \
# 48176   19870214.0      1.0  659130.0  25.0          13000.0  ...           0
# 89187   19890803.0      1.0  344808.0  23.0           9500.0  ...           0
# 128178  19850101.0      1.0  622150.0  27.0          15000.0  ...           0
# 25482   19880201.0      1.0  182007.0  24.0          15000.0  ...           0
# 68298   19670225.0      1.0  287810.0  45.0          20000.0  ...           0
#
#         province_M  province_N  province_O  group_B  group_C  group_D  \
# 48176            0           0           0        1        0        0
# 89187            0           0           0        1        0        0
# 128178           0           0           0        1        0        0
# 25482            0           0           0        0        0        0
# 68298            0           0           0        1        0        0
#
#         history_type_B  history_type_C  history_type_D
# 48176                1               0               0
# 89187                0               0               0
# 128178               0               1               0
# 25482                1               0               0
# 68298                0               1               0
#
# [5 rows x 35 columns]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30913 entries, 48176 to 132723
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              30913 non-null  float64
#  1   user_id            30913 non-null  int64
#  2   registration_date  30913 non-null  float64
#  3   family_size        30913 non-null  float64
#  4   loan_amount        30913 non-null  int64
#  5   birth_date         30913 non-null  float64
#  6   is_male            30913 non-null  float64
#  7   zip_code           30913 non-null  float64
#  8   age                30913 non-null  float64
#  9   monthly_expense    30913 non-null  float64
#  10  edu_career_years   9159 non-null   float64
#  11  contract_type_B    30913 non-null  uint8
#  12  contract_type_C    30913 non-null  uint8
#  13  contract_type_D    30913 non-null  uint8
#  14  contract_type_E    30913 non-null  uint8
#  15  province_B         30913 non-null  uint8
#  16  province_C         30913 non-null  uint8
#  17  province_D         30913 non-null  uint8
#  18  province_E         30913 non-null  uint8
#  19  province_F         30913 non-null  uint8
#  20  province_G         30913 non-null  uint8
#  21  province_H         30913 non-null  uint8
#  22  province_I         30913 non-null  uint8
#  23  province_J         30913 non-null  uint8
#  24  province_K         30913 non-null  uint8
#  25  province_L         30913 non-null  uint8
#  26  province_M         30913 non-null  uint8
#  27  province_N         30913 non-null  uint8
#  28  province_O         30913 non-null  uint8
#  29  group_B            30913 non-null  uint8
#  30  group_C            30913 non-null  uint8
#  31  group_D            30913 non-null  uint8
#  32  history_type_B     30913 non-null  uint8
#  33  history_type_C     30913 non-null  uint8
#  34  history_type_D     30913 non-null  uint8
# dtypes: float64(9), int64(2), uint8(24)
# memory usage: 3.5 MB

# %% [markdown]
# **Normalizing with MinMaxScaler**

# %%
# Initialize the MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %% [markdown]
# **Resampling Target Feature**

# %%
# over sampling target feature
from imblearn.over_sampling import SMOTE

s = {0: 102220, 1: 102220}  # number of oversampling in class is greater than original number

# Fit and transform the training data (X_train, y_train) using SMOTE
X_train_resampled, y_train_resampled = SMOTE(sampling_strategy= s, random_state= seed).fit_resample(X_train, y_train)

# %%
y_train_resampled.value_counts()
# Out:
# 0.0    102220
# 1.0    102220
# Name: default_value, dtype: int64

# %% [markdown]
# ***inspecting our testing data***

# %%
X_test.head()
# Out:
#              month  user_id  registration_date  family_size  loan_amount  \
# 48176   20120801.0   981768         20121105.0          2.0       108378
# 89187   20130601.0   976840         20120605.0          2.0       153996
# 128178  20120701.0   838565         20120130.0          4.0       165399
# 25482   20120701.0   797763         20120401.0          0.0       135321
# 68298   20130201.0  1020410         20120206.0          2.0       171408
#
#         birth_date  is_male  zip_code   age  monthly_expense  ...  province_L  \
# 48176   19870214.0      1.0  659130.0  25.0          13000.0  ...           0
# 89187   19890803.0      1.0  344808.0  23.0           9500.0  ...           0
# 128178  19850101.0      1.0  622150.0  27.0          15000.0  ...           0
# 25482   19880201.0      1.0  182007.0  24.0          15000.0  ...           0
# 68298   19670225.0      1.0  287810.0  45.0          20000.0  ...           0
#
#         province_M  province_N  province_O  group_B  group_C  group_D  \
# 48176            0           0           0        1        0        0
# 89187            0           0           0        1        0        0
# 128178           0           0           0        1        0        0
# 25482            0           0           0        0        0        0
# 68298            0           0           0        1        0        0
#
#         history_type_B  history_type_C  history_type_D
# 48176                1               0               0
# 89187                0               0               0
# 128178               0               1               0
# 25482                1               0               0
# 68298                0               1               0
#
# [5 rows x 35 columns]

# %%
y_test.head()
# Out:
#         default_value
# 48176               0
# 89187               0
# 128178              0
# 25482               0
# 68298               0

# %% [markdown]
# **Saving our split data on CSV**

# %%
# our train data normalized (post smote) is in array type
np.savetxt('X_train_resampled.csv', X_train_resampled, delimiter=',')

# %%
# our train target feature data is not normalized but post smote is in series type
df_ytrain = pd.DataFrame(y_train_resampled)

# %%
df_ytrain.to_csv('y_train_resampled.csv', index=True)

# %%
X_test.to_csv('X_test.csv', index=True)
y_test.to_csv('y_test.csv', index =True)

# %% [markdown]
#  **Pre Processing Report**
# ---
#
#
# >
#
#
# Our **Testing data** is untouched except for 2 aspects. applying the pre-processing function which encodes our features into numerical type. There are still null values.
#
# Some models do not accept nulll value inputs. Logistic Regression for example, only allows non null numerical values.
#
# We also dropped 2 feature columns and applied additional arithmetic to the testing data. This is okay to do because in production, the inputing data can also be altered the same way as it makes sense to do so.
# >
#
#
# Our **Training data** is preprocessed and transformed in the following ways.
#
# For `*Data Engineering*`, multicolinearity is dealt with creating new features using additiion arithmetics. Addition is used because of the relational sematics of the 2 correlated features. We also remove outliers of highly correlated features using IQR math applications. It is visualized with box plots. This is important for null value imputation as we are using a regressor model and removing outliers reduce bias and variance. Since the outliers are few considering the size of the dataset, we can consider omitting them.
#
# Due to high number of null values in the training data, it is imputed with the `MICE algorithm`. This is more accurate than using arithmetic imputation as it is a multivariate regressor. The imputed values are estimated by other numerical features.
#
# The training data also uses `SMOTE` to balance the weight of our target feature. This is important as unbalanced training data will affect the model evalation. There may be more false positives and more false negatives due to the bias of unweighted target feature. We use oversampling method for the default counts.

# %% [markdown]
# ## **Histogram Gradient Boosting Classifier Model Implementation**

# %%
# clear the model state

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.experimental import enable_hist_gradient_boosting

# %%
hgb_clf = HistGradientBoostingClassifier()
hgb_clf.fit(X_train_resampled, y_train_resampled)
y_pred = hgb_clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy 82.67072105586647

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[25556     0]
#  [ 5357     0]]

# %%
from mlxtend.plotting import plot_confusion_matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat= cm, figsize=(6, 6), cmap=plt.cm.Greens)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters_hgb = [{'max_iter': [1000,1200,1500],
                'learning_rate': [0.1],
                'max_depth' : [25, 50, 75],
                'l2_regularization': [1.5],
                'scoring': ['f1_micro']}]

grid_search_hgb = GridSearchCV(estimator = hgb_clf,
                           param_grid = parameters_hgb,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search_hgb.fit(X_train_resampled, y_train_resampled)
best_accuracy_hgb = grid_search_hgb.best_score_
best_paramaeter_hgb = grid_search_hgb.best_params_
print("Best Accuracy of HGB: {:.2f} %".format(best_accuracy_hgb.mean()*100))
print("Best Parameter of HGB:", best_paramaeter_hgb)
